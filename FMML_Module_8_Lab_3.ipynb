# %% [markdown]
# <a href="https://colab.research.google.com/github/LathaPati/FMML_COURSE_ASSIGNMENT/blob/main/FMML_Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-27 14:32:31--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   195MB/s    in 0.4s
#
# 2023-05-27 14:32:34 (195 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22794  1706.09880v4  Interpreting gradient methods as fixed-point i...  stat
# 25572  1510.02413v1  We propose a data-driven approach for intrinsi...    cs
# 33351   1304.1978v2  Geometric discrepancies are standard measures ...    cs
# 17746  1802.06196v1  Distributed representations of words learned f...    cs
# 27307  1703.02168v1  Recently, convolutional neural networks (CNN) ...    cs
# ...             ...                                                ...   ...
# 21060  1707.03744v1  We propose a novel method for automatic progra...    cs
# 21922  1503.01442v2  Many high dimensional sparse learning problems...  stat
# 35856   1301.6711v1  Poker is ideal for testing automated reasoning...    cs
# 7424   1712.07454v1  A significantly faster algorithm is presented ...  stat
# 18043  cs/0207030v2  An extension of an abstract argumentation fram...    cs
#
#                                                    title  year  \
# 22794  A Fixed-Point of View on Gradient Methods for ...  2017
# 25572  Learning Data-driven Reflectance Priors for In...  2015
# 33351  Constructing Low Star Discrepancy Point Sets w...  2013
# 17746  Can Network Embedding of Distributional Thesau...  2018
# 27307                                 Deep View Morphing  2017
# ...                                                  ...   ...
# 21060                                 P-Tree Programming  2017
# 21922           Statistical Limits of Convex Relaxations  2015
# 35856                                     Bayesian Poker  2013
# 7424   Fast kNN mode seeking clustering applied to ac...  2017
# 18043                           Collective Argumentation  2002
#
#                                                 keywords
# 22794  [interpreting, iterations, minimizing, objecti...
# 25572  [intrinsic, decomposition, inferring, confound...
# 33351  [geometric, discrepancies, irregularity, distr...
# 17746  [distributed, representations, successful, pro...
# 27307  [convolutional, successfully, synthesis, disto...
# ...                                                  ...
# 21060  [automatic, synthesis, programming, represents...
# 21922  [dimensional, formulated, nonconvex, optimizat...
# 35856  [automated, reasoning, uncertainty, introduces...
# 7424   [significantly, algorithm, presented, procedur...
# 18043  [extension, argumentation, framework, collecti...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22794    [interpreting, iterations, minimizing, objecti...
# 25572    [intrinsic, decomposition, inferring, confound...
# 33351    [geometric, discrepancies, irregularity, distr...
# 17746    [distributed, representations, successful, pro...
# 27307    [convolutional, successfully, synthesis, disto...
#                                ...
# 40772    [selection, tremendous, variables, diagnosis, ...
# 15728    [introduced, childrens, associated, comprehens...
# 22575    [algorithms, attractive, desirable, properties...
# 26840    [principled, estimation, advantages, convoluti...
# 10472    [combination, maximizes, advantages, interpret...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8820 words.
# Out of those 4575 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ae9f01db-2294-4464-9c75-7a1a794ea74f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae9f01db-2294-4464-9c75-7a1a794ea74f")) {                    Plotly.newPlot(                        "ae9f01db-2294-4464-9c75-7a1a794ea74f",                        [{"x":["functions","considered","algorithmic","conveniently","particular","iterations","conceptual","interpreting","simplicity","properties","accelerations","transformation","derivation","accelerated","minimizing","objective","gradients","convergence","preserving","demonstrate","associated","stochastic","naturally","especially","intrinsic","integrate","confounding","minimization","frameworks","conditions","relighting","annotations","challenging","inferring","demonstrating","producing","decomposition","reflectance","numerical","constructing","approximation","algorithm","integration","principles","evolutionary","outperforms","discrepancy","approaches","evaluation","geometric","algorithms","distributions","important","components","optimization","irregularity","knowledge","discrepancies","predictive","thesaurus","comparable","investigate","representations","processing","structure","techniques","significant","embedding","neighborhood","representation","similarity","relatedness","evaluated","additionally","represent","performance","handcrafted","combining","successful","usefulness","distributional","detection","distributed","resources","motivated","improving","synthesis","successfully","generates","visibility","synthesizes","computational","experimentally","rectification","distortions","rectified","convolutional","complexity","correspondences","synthesize","significantly","architecture","traditional","uncertain","containing","configurations","simulation","prediction","previously","perception","observations","understanding","comprised","bypassing","quantities","stability","different","application","appearance","simulated","potential","psychology","developmental","judgments","synthetic","competence","manipulation","phenomena","environments","architectural","mechanism","precision","including","existence","conditioned","developments","incorporated","utterances","computing","attention","supervised","considerably","fundamentals","improvement","calculated","quantitative","demonstrates","operating","investing","outperform","portfolio","simulator","enterprise","capitalization","financial","retrospective","normalized","identified","forecasting","companies","portfolios","neuromorphic","structural","formation","interconnected","unsupervised","accuracies","reservoirs","classification","generality","retaining","recognition","separations","generally","furthermore","recurrent","respectively","connections","plasticity","generalization","evolution","protocols","generating","iteratively","separation","modification","connection","elimination","reservoir","resolution","biological","investigating","robustness","considers","superiority","coefficients","projection","extensive","proposing","determined"],"y":[221,154,41,4,287,35,15,11,25,224,1,50,12,13,65,160,33,122,57,584,110,136,59,127,44,40,3,68,39,156,3,40,266,32,35,35,68,8,80,40,126,831,47,45,66,299,12,407,267,73,622,116,347,97,312,2,322,5,56,5,82,118,246,272,353,358,250,107,33,384,154,10,149,75,98,917,15,105,66,28,29,339,103,58,54,92,52,79,58,10,7,275,55,5,14,10,366,248,22,15,261,245,174,31,65,22,80,246,84,39,75,152,7,4,17,35,761,244,79,69,147,8,5,9,151,2,18,24,80,10,118,81,245,41,23,16,32,15,129,174,202,20,1,145,33,61,40,20,1,89,6,7,1,2,12,1,33,47,15,7,0,9,84,11,4,174,34,2,543,21,8,367,2,61,174,145,88,60,4,115,66,14,104,45,28,22,45,13,7,130,36,16,108,39,29,38,58,165,13,34],"type":"bar"},{"x":["functions","considered","algorithmic","conveniently","particular","itera ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4575,), (4575, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7891666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Difficulties</span> <span style=''>of</span> <span style=''>Learning</span> <span style=''>Logic</span> <span style=''>Programs</span> <span style=''>with</span> <span style=''>Cut</span> <br/><br/><span style=''>As</span> <span style=''>real</span> <span style=''>logic</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>programmers</span> <span style=''>normally</span> <span style=''>use</span> <span style=''>cut</span> <span style=''>()</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3180661577608142);'>effective</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>for</span> <span style=''>logic</span> <span style=''>programs</span> <span style=''>should</span> <span style=''>be</span> <span style=''>able</span> <span style=''>to</span> <span style=''>deal</span> <span style=''>with</span> <span style=''>it</span> <span style=''>Because</span> <span style=''>the</span> <span style=''>cut</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>predicate</span> <span style=''>has</span> <span style=''>only</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>procedural</span> <span style=''>meaning</span> <span style=''>clauses</span> <span style='background-color:rgba(0, 255, 0, 0.4444444444444444);'>containing</span> <span style=''>cut</span> <span style=''>cannot</span> <span style=''>be</span> <span style=''>learned</span> <span style=''>using</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>extensional</span> <span style='background-color:rgba(0, 255, 0, 0.4202127659574468);'>evaluation</span> <span style=''>method</span> <span style=''>as</span> <span style=''>is</span> <span style=''>done</span> <span style=''>in</span> <span style=''>most</span> <span style=''>learning</span> <span style=''>systems</span> <span style=''>On</span> <span style=''>the</span> <span style=''>other</span> <span style=''>hand</span> <span style='background-color:rgba(0, 255, 0, 0.627906976744186);'>searching</span> <span style=''>a</span> <span style=''>space</span> <span style=''>of</span> <span style=''>possible</span> <span style=''>programs</span> <span style=''>(instead</span> <span style=''>of</span> <span style=''>a</span> <span style=''>space</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>clauses)</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unfeasible</span> <span style=''>An</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternative</span> <span style=''>solution</span> <span style=''>is</span> <span style=''>to</span> <span style=''>generate</span> <span style=''>first</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>candidate</span> <span style=''>base</span> <span style=''>program</span> <span style=''>which</span> <span style=''>covers</span> <span style=''>the</span> <span style=''>positive</span> <span style=''>examples</span> <span style=''>and</span> <span style=''>then</span> <span style=''>make</span> <span style=''>it</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>inserting</span> <span style=''>cut</span> <span style=''>where</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>appropriate</span> <span style=''>The</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>programs</span> <span style=''>with</span> <span style=''>cut</span> <span style=''>has</span> <span style=''>not</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigated</span> <span style=''>before</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Ellipsoidal</span> <span style=''>Rounding</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonnegative</span> <span style=''>Matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Factorization</span> <span style=''>Under</span> <span style=''>Noisy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Separability</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>numerical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonnegative</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorization</span> <span style=''>(NMF)</span> <span style=''>problems</span> <span style=''>under</span> <span style=''>noisy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separability</span> <span style=''>An</span> <span style=''>NMF</span> <span style=''>problem</span> <span style=''>under</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separability</span> <span style=''>can</span> <span style=''>be</span> <span style=''>stated</span> <span style=''>as</span> <span style=''>one</span> <span style=''>of</span> <span style=''>finding</span> <span style=''>all</span> <span style=''>vertices</span> <span style=''>of</span> <span style=''>the</span> <span style=''>convex</span> <span style=''>hull</span> <span style=''>of</span> <span style=''>data</span> <span style=''>points</span> <span style=''>The</span> <span style=''>research</span> <span style=''>interest</span> <span style=''>of</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>to</span> <span style=''>find</span> <span style=''>the</span> <span style=''>vectors</span> <span style=''>as</span> <span style=''>close</span> <span style=''>to</span> <span style=''>the</span> <span style=''>vertices</span> <span style=''>as</span> <span style=''>possible</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>situation</span> <span style=''>in</span> <span style=''>which</span> <span style=''>noise</span> <span style=''>is</span> <span style=''>added</span> <span style=''>to</span> <span style=''>the</span> <span style=''>data</span> <span style=''>points</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>capture</span> <span style=''>the</span> <span style=''>shape</span> <span style=''>of</span> <span style=''>the</span> <span style=''>convex</span> <span style=''>hull</span> <span style=''>of</span> <span style=''>data</span> <span style=''>points</span> <span style=''>by</span> <span style=''>using</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>enclosing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ellipsoid</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>has</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correctness</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perspectives</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correctness</span> <span style=''>here</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>reducing</span> <span style=''>sampling</span> <span style=''>variance</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.5384615384615384);'>covariate</span> <span style=''>shift</span> <span style=''>using</span> <span style=''>control</span> <span style=''>variates</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.5384615384615384);'>Covariate</span> <span style=''>shift</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>problems</span> <span style=''>can</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>be</span> <span style=''>tackled</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>weighting</span> <span style=''>training</span> <span style=''>samples</span> <span style=''>However</span> <span style=''>the</span> <span style=''>sampling</span> <span style=''>variance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.7090909090909091);'>estimator</span> <span style=''>is</span> <span style=''>often</span> <span style=''>scaled</span> <span style=''>up</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dramatically</span> <span style=''>by</span> <span style=''>the</span> <span style=''>weights</span> <span style=''>This</span> <span style=''>means</span> <span style=''>that</span> <span style=''>during</span> <span style=''>cross</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>validation</span> <span style=''>when</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>weighted</span> <span style=''>risk</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.4117647058823529);'>repeatedly</span> <span style='background-color:rgba(0, 255, 0, 0.4258373205741626);'>evaluated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>suboptimal</span> <span style='background-color:rgba(255, 0, 0, 0.38095238095238104);'>hyperparameter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimates</span> <span style=''>are</span> <span style=''>produced</span> <span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>variances</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>weighted</span> <span style=''>versus</span> <span style=''>the</span> <span style=''>oracle</span> <span style='background-color:rgba(255, 0, 0, 0.7090909090909091);'>estimator</span> <span style=''>as</span> <span style=''>a</span> <span style=''>function</span> <span style=''>of</span> <span style=''>the</span> <span style=''>relative</span> <span style=''>scale</span> <span style=''>of</span> <span style=''>the</span> <span style=''>training</span> <span style=''>data</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introducing</span> <span style=''>a</span> <span style=''>control</span> <span style=''>variate</span> <span style=''>can</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>variance</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>weighted</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.7090909090909091);'>estimator</span> <span style=''>which</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>superior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Grafting</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Combinatorial</span> <span style=''>Boolean</span> <span style=''>Model</span> <span style=''>using</span> <span style=''>Frequent</span> <span style=''>Itemset</span> <span style=''>Mining</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combinatorial</span> <span style=''>Boolean</span> <span style=''>model</span> <span style=''>(CBM)</span> <span style=''>which</span> <span style=''>is</span> <span style=''>defined</span> <span style=''>as</span> <span style=''>the</span> <span style=''>class</span> <span style=''>of</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combinations</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conjunctions</span> <span style=''>of</span> <span style=''>Boolean</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attributes</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>addresses</span> <span style=''>the</span> <span style=''>issue</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>CBM</span> <span style=''>from</span> <span style=''>labeled</span> <span style=''>data</span> <span style=''>CBM</span> <span style=''>is</span> <span style=''>of</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>but</span> <span style=''>naive</span> <span style=''>learning</span> <span style=''>of</span> <span style=''>it</span> <span style=''>requires</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exponentially</span> <span style=''>large</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>time</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>and</span> <span style=''>sample</span> <span style=''>size</span> <span style=''>To</span> <span style=''>overcome</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficulty</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>GRAB</span> <span style=''>(GRAfting</span> <span style=''>for</span> <span style=''>Boolean</span> <span style=''>datasets)</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style=''>learns</span> <span style=''>CBM</span> <span style=''>within</span> <span style=''>the</span> <span style=''>L</span> <span style=''>1</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularized</span> <span style=''>loss</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>The</span> <span style=''>key</span> <span style=''>idea</span> <span style=''>of</span> <span style=''>GRAB</span> <span style=''>is</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>loss</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style=''>problem</span> <span style=''>to</span> <span style=''>the</span> <span style=''>weighted</span> <span style=''>frequent</span> <span style=''>itemset</span> <span style=''>mining</span> <span style=''>in</span> <span style=''>which</span> <span style=''>freq ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	reasoning (0.050515830665243684)
# 	experimental (0.14194236926360726)
# 	architecture (0.08715759516186411)
# 	segmentation (0.07186054784774101)
# 	representation (0.13660618996798293)
# 	information (0.24688722874421914)
# 	detection (0.12059765208110992)
# 	recognition (0.1305585200996087)
# 	convolutional (0.13020277481323372)
# 	different (0.27072216293134116)
#
# Some Statistics words are:
# 	variational (0.10910005027652087)
# 	algorithm (0.38964303670186023)
# 	variables (0.14580191050779287)
# 	theoretical (0.15434891905480141)
# 	estimation (0.18099547511312217)
# 	distribution (0.1895424836601307)
# 	statistical (0.1583710407239819)
# 	regression (0.17747611865258925)
# 	dimensional (0.19658119658119658)
# 	inference (0.2106586224233283)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b0ac519a-95c7-4401-9ff7-459fa0ab46c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0ac519a-95c7-4401-9ff7-459fa0ab46c9")) {                    Plotly.newPlot(                        "b0ac519a-95c7-4401-9ff7-459fa0ab46c9",                        [{"x":["functions","considered","algorithmic","conveniently","particular","iterations","conceptual","interpreting","simplicity","properties","accelerations","transformation","derivation","accelerated","minimizing","objective","gradients","convergence","preserving","demonstrate","associated","stochastic","naturally","especially","intrinsic","integrate","confounding","minimization","frameworks","conditions","relighting","annotations","challenging","inferring","demonstrating","producing","decomposition","reflectance","numerical","constructing","approximation","algorithm","integration","principles","evolutionary","outperforms","discrepancy","approaches","evaluation","geometric","algorithms","distributions","important","components","optimization","irregularity","knowledge","discrepancies","predictive","thesaurus","comparable","investigate","representations","processing","structure","techniques","significant","embedding","neighborhood","representation","similarity","relatedness","evaluated","additionally","represent","performance","handcrafted","combining","successful","usefulness","distributional","detection","distributed","resources","motivated","improving","synthesis","successfully","generates","visibility","synthesizes","computational","experimentally","rectification","distortions","rectified","convolutional","complexity","correspondences","synthesize","significantly","architecture","traditional","uncertain","containing","configurations","simulation","prediction","previously","perception","observations","understanding","comprised","bypassing","quantities","stability","different","application","appearance","simulated","potential","psychology","developmental","judgments","synthetic","competence","manipulation","phenomena","environments","architectural","mechanism","precision","including","existence","conditioned","developments","incorporated","utterances","computing","attention","supervised","considerably","fundamentals","improvement","calculated","quantitative","demonstrates","operating","investing","outperform","portfolio","simulator","enterprise","capitalization","financial","retrospective","normalized","identified","forecasting","companies","portfolios","neuromorphic","structural","formation","interconnected","unsupervised","accuracies","reservoirs","classification","generality","retaining","recognition","separations","generally","furthermore","recurrent","respectively","connections","plasticity","generalization","evolution","protocols","generating","iteratively","separation","modification","connection","elimination","reservoir","resolution","biological","investigating","robustness","considers","superiority","coefficients","projection","extensive","proposing","determined","determine","guarantees","experimental","dimension","dimensional","advantages","automatic","reconstruction","simultaneously","automatically","efficiency","underlying","theoretical","databases","principal","subspaces","discriminative","differences","recognizing","subcategories","comparing","classifiers","eliminate","dependence","accelerates","framework","localization","essential","reflecting","accelerate","limitations","therefore","novelties","consuming","directional","hypotheses","typically","optimizes","corresponds","likelihood","effective","evaluations","criterion","procedure","approximate","interesting","implement","searching","retrieving","independent","observation","converted","sublinear","phenomenon","recommendations ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	portfolios
# 	sparsistency
# 	offerings
# 	bernstein
# 	unavoidably
# 	approachability
# 	approachable
# 	subsample
# 	unpenalized
# 	dependences
# 	notations
# 	specialist
# 	sparsities
# 	disaggregation
# 	identifiability
# 	subpopulations
# 	polyhedral
# 	independences
# 	changepoint
# 	homogeneity
# Some words which never appear in Statistics papers:
# 	relighting
# 	irregularity
# 	thesaurus
# 	rectification
# 	psychology
# 	competence
# 	reservoirs
# 	binarizes
# 	concatenation
# 	referenced
# 	familiarity
# 	taxonomies
# 	disambiguate
# 	enriching
# 	conceptualization
# 	preprocessed
# 	avoidance
# 	sarcastic
# 	overwhelmed
# 	suppliers

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.059507419305492e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7316666666666667
